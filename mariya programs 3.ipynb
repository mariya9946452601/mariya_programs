# %%
string = input("Enter a string: ")

new_string = string[-1] + string[1:-1] + string[0]

print("New string:", new_string)
# Out:
# Enter a string: mariya
# New string: aariym

# %%
string = input("Enter a string: ")

new_string = string[:2] + string[-2:]

print("New string:", new_string)
# Out:
# Enter a string: mariya
# New string: maya

# %%
string1 = input("Enter first string: ")
string2 = input("Enter second string: ")

new_string1 = string2[0] + string1[1:]
new_string2 = string1[0] + string2[1:]

result = new_string1 + " " + new_string2

print("Result:", result)
# Out:
# Enter first string: mariya
# Enter second string: miha
# Result: mariya miha

# %%
string = input("Enter a string: ")

result = string[0] + string[1:].replace(string[0], "$")

print("New string:", result)
# Out:
# Enter a string: babble
# New string: ba$$le
