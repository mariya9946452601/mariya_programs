# %%
num=int (input("Enter a number:"))
num1=num
num2=num*10+num1
num3=num*100+num2
print(num1,num2,num3,"=",num1+num2+num3)
# Out:
# Enter a number:3
# 3 33 333 = 369

# %%
from math import pi
r=int(input("enter the radius of circle:"))
area=pi*r*r
print("area of circle:",f"{area:.2f}")
# Out:
# enter the radius of circle:3
# area of circle: 28.27

# %%
a=int(input("enter the first number:"))
b=int(input("enter the second number:"))
c=int(input("enter the third number:"))
biggest=max(a,b,c)
print("biggest number among these=",biggest)
# Out:
# enter the first number:1
# enter the second number:2
# enter the third number:8
# biggest number among these= 8

# %%
# Out:
# Enter the temperature in celsius:2
# The corresponding fahrenheit: 35.6

# %%
# Out:
# Enter the distance inkilometrs:4
# the corresponding miles: 2.49
